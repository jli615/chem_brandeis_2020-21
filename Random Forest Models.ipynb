# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import svm, tree
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor, plot_tree, export_graphviz
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_validate, cross_val_score, cross_val_predict, LeaveOneOut
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

import random
from datetime import datetime

# %%
solvent_data = pd.read_excel('/Users/jlisd/Downloads/AI Chem/AI Chem/Holistic prediction of enantioselectivity in asymmetric catalysis.Supplementary Data.xlsx', sheet_name = 'solvent')
solvent_data.set_index('solvent_name', inplace = True)
solvent_columns = list(solvent_data.columns)

# %%
nucleophile_data = pd.read_excel('/Users/jlisd/Downloads/AI Chem/AI Chem/Holistic prediction of enantioselectivity in asymmetric catalysis.Supplementary Data.xlsx', sheet_name = 'nucleophiles')
nucleophile_data.set_index('nucleophile_name', inplace = True)
nucleophile_columns = list(nucleophile_data.columns)

# %%
raw_catalyst_data = pd.read_excel('/Users/jlisd/Downloads/AI Chem/AI Chem/Holistic prediction of enantioselectivity in asymmetric catalysis.Supplementary Data.xlsx', sheet_name = 'full_catalyst')
raw_catalyst_data.rename(columns = {'last catalyst only S used': 'catalyst_name'}, inplace = True)

r_catalyst_data = raw_catalyst_data.copy()
for i in range(17):
    r_catalyst_data.iloc[i, 1] = r_catalyst_data.iloc[i, 1].replace('R/S', 'R')

s_catalyst_data = raw_catalyst_data.copy()
for i in range(17):
    s_catalyst_data.iloc[i, 1] = s_catalyst_data.iloc[i, 1].replace('R/S', 'S')

catalyst_data = pd.concat([r_catalyst_data, s_catalyst_data])
catalyst_data.set_index('catalyst_name', inplace = True)
catalyst_columns = list(catalyst_data.columns)

# %%
raw_catalyst_data = pd.read_excel('/Users/jlisd/Downloads/AI Chem/AI Chem/Holistic prediction of enantioselectivity in asymmetric catalysis.Supplementary Data.xlsx', sheet_name = 'full_catalyst')
raw_catalyst_data.rename(columns = {'last catalyst only S used': 'catalyst_name'}, inplace = True)

#Taking care of catalyst R/S
r_catalyst_data = raw_catalyst_data.copy()
for i in range(17):
    r_catalyst_data.iloc[i, 1] = r_catalyst_data.iloc[i, 1].replace('R/S', 'R')
    #print(r_catalyst_data.iloc[i, 1])
#r_catalyst_data.drop(17, inplace = True)    

s_catalyst_data = raw_catalyst_data.copy()
for i in range(17):
    s_catalyst_data.iloc[i, 1] = s_catalyst_data.iloc[i, 1].replace('R/S', 'S')
    #print(s_catalyst_data.iloc[i, 1])
    
catalyst_data = pd.concat([r_catalyst_data, s_catalyst_data])
catalyst_data.rename(columns = {'last catalyst only S used': 'catalyst_name'}, inplace = True)
catalyst_data.set_index('catalyst_name', inplace = True)

catalyst_columns = list(catalyst_data.columns)

catalyst_data
# Out:
#                                                                 Ar group  \
# catalyst_name
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...                    Ph
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...             4-NO2C6H4
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  4-(2,4,6-MeC6H2)C6H4
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...              4-ClC6H4
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...              4-PhC6H4
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...             4-CF3C6H4
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...           3,5-NO2C6H3
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...            3,5-PhC6H3
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...       3,5-(CF3)2-C6H3
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...             9-Anthryl
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...         9-Phenanthryl
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...            1-naphthyl
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...            2-naphthyl
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...         2,4,6-iPrC6H2
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...          2,4,6-MeC6H2
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...            2,6-MeC6H3
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...          2,4,6-CyC6H2
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...    H8-3,5-(CF3)2-C6H3
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...                    Ph
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...             4-NO2C6H4
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  4-(2,4,6-MeC6H2)C6H4
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...              4-ClC6H4
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...              4-PhC6H4
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...             4-CF3C6H4
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...           3,5-NO2C6H3
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...            3,5-PhC6H3
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...       3,5-(CF3)2-C6H3
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...             9-Anthryl
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...         9-Phenanthryl
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...            1-naphthyl
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...            2-naphthyl
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...         2,4,6-iPrC6H2
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...          2,4,6-MeC6H2
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...            2,6-MeC6H3
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...          2,4,6-CyC6H2
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...    H8-3,5-(CF3)2-C6H3
#
#                                                       arhs    alhs     aavg  \
# catalyst_name
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  54.388  54.395  54.3915
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  52.789  52.801  52.7950
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  53.962  53.963  53.9625
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  53.704  53.718  53.7110
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  42.215  52.094  47.1545
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  53.619  53.627  53.6230
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  59.563  59.562  59.5625
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  42.585  60.259  51.4220
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  55.665  55.883  55.7740
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  78.854  78.853  78.8535
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  62.831  62.828  62.8295
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  63.920  63.925  63.9225
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  55.015  51.696  53.3555
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  73.713  72.861  73.2870
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  76.489  76.487  76.4880
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  76.312  76.317  76.3145
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  74.179  74.164  74.1715
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  54.427  54.027  54.2270
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  54.388  54.395  54.3915
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  52.789  52.801  52.7950
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  53.962  53.963  53.9625
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  53.704  53.718  53.7110
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  42.215  52.094  47.1545
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  53.619  53.627  53.6230
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  59.563  59.562  59.5625
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  42.585  60.259  51.4220
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  55.665  55.883  55.7740
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  78.854  78.853  78.8535
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  62.831  62.828  62.8295
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  63.920  63.925  63.9225
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  55.015  51.696  53.3555
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  73.713  72.861  73.2870
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  76.489  76.487  76.4880
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  76.312  76.317  76.3145
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  74.179  74.164  74.1715
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  54.427  54.027  54.2270
#
#                                                          b  AREA(q)  \
# catalyst_name
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  56.388       70
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  56.202       64
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  56.355       38
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  56.219       67
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  55.769       50
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  56.229       56
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  55.628       66
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  54.746       36
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  56.229       62
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  55.161       61
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  56.630       48
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  56.643       62
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  56.300       49
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  54.231       51
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  54.871       61
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  54.961       68
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  54.611       47
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  59.959       62
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  56.388       70
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  56.202       64
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  56.355       38
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  56.219       67
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  55.769       50
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  56.229       56
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  55.628       66
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  54.746       36
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  56.229       62
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  55.161       61
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  56.630       48
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  56.643       62
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  56.300       49
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  54.231       51
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  54.871       61
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  54.961       68
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  54.611       47
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  59.959       62
#
#                                                     sin(AREA)  Lwhole R  \
# catalyst_name
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...   0.773891      6.89
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...   0.920026      8.28
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...   0.296369     12.27
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  -0.855520      8.21
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  -0.262375     11.22
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  -0.521551      8.28
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  -0.026551      7.58
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  -0.991779      8.59
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  -0.739181      7.44
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  -0.966118      6.94
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  -0.768255      8.96
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  -0.739181      6.97
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  -0.953753      8.99
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...   0.670229      9.09
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  -0.966118      7.94
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  -0.897928      6.88
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...   0.123573     11.16
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  -0.739181      7.45
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...   0.773891      6.89
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...   0.920026      8.28
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...   0.296369     12.27
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  -0.855520      8.21
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  -0.262375     11.22
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  -0.521551      8.28
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  -0.026551      7.58
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  -0.991779      8.59
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  -0.739181      7.44
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  -0.966118      6.94
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  -0.768255      8.96
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  -0.739181      6.97
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  -0.953753      8.99
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...   0.670229      9.09
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  -0.966118      7.94
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  -0.897928      6.88
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...   0.123573     11.16
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  -0.739181      7.45
#
#                                                     B1whole R  B5whole R  ...  \
# catalyst_name                                                             ...
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...       1.70       3.33  ...
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...       1.70       3.34  ...
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...       2.97       4.61  ...
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...       1.70       3.33  ...
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...       2.01       3.50  ...
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...       1.83       3.34  ...
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...       1.70       5.12  ...
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...       2.59       7.06  ...
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...       2.39       5.06  ...
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...       1.73       5.72  ...
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...       1.72       5.73  ...
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...       1.71       5.73  ...
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...       1.70       4.58  ...
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...       3.23       5.67  ...
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...       1.83       4.48  ...
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...       1.82       4.48  ...
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...       3.27       7.58  ...
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...       2.49       5.06  ...
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...       1.70       3.33  ...
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...       1.70       3.34  ...
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...       2.97       4.61  ...
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...       1.70       3.33  ...
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...       2.01       3.50  ...
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...       1.83       3.34  ...
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...       1.70       5.12  ...
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...       2.59       7.06  ...
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...       2.39       5.06  ...
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...       1.73       5.72  ...
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...       1.72       5.73  ...
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...       1.71       5.73  ...
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...       1.70       4.58  ...
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...       3.23       5.67  ...
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...       1.83       4.48  ...
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...       1.82       4.48  ...
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...       3.27       7.58  ...
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...       2.49       5.06  ...
#
#                                                        C3 A     C4 A     C5 A  \
# catalyst_name
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha... -0.23000 -0.22400 -0.21100
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2... -0.17700  0.01000 -0.19500
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1... -0.20700 -0.05300 -0.22300
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,... -0.23200 -0.03000 -0.25000
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d... -0.19550 -0.06650 -0.20200
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina... -0.19300 -0.17200 -0.17700
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  0.02900 -0.17300  0.01300
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy... -0.04700 -0.18750 -0.05650
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,... -0.14850 -0.16150 -0.16650
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d... -0.05400 -0.16200 -0.05900
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-... -0.05200 -0.03700 -0.03600
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,... -0.19800 -0.19700 -0.06600
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,... -0.12350 -0.06400 -0.13350
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin... -0.22750 -0.00855 -0.23050
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph... -0.22100 -0.02100 -0.22600
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy... -0.22200 -0.20900 -0.22800
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl... -0.22248 -0.00641 -0.22731
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-... -0.15100 -0.16500 -0.16800
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha... -0.23000 -0.22400 -0.21100
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2... -0.17700  0.01000 -0.19500
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1... -0.20700 -0.05300 -0.22300
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,... -0.23200 -0.03000 -0.25000
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d... -0.19550 -0.06650 -0.20200
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina... -0.19300 -0.17200 -0.17700
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  0.02900 -0.17300  0.01300
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy... -0.04700 -0.18750 -0.05650
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,... -0.14850 -0.16150 -0.16650
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d... -0.05400 -0.16200 -0.05900
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-... -0.05200 -0.03700 -0.03600
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,... -0.19800 -0.19700 -0.06600
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,... -0.12350 -0.06400 -0.13350
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin... -0.22750 -0.00855 -0.23050
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph... -0.22100 -0.02100 -0.22600
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy... -0.22200 -0.20900 -0.22800
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl... -0.22248 -0.00641 -0.22731
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-... -0.15100 -0.16500 -0.16800
#
#                                                         C6 A    nPOsy  \
# catalyst_name
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha... -0.186000  1085.06
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2... -0.207000  1086.44
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1... -0.199000  1085.55
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,... -0.190000  1085.19
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d... -0.183500  1087.44
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina... -0.184000  1086.23
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy... -0.154000  1087.41
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy... -0.171500  1085.98
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,... -0.157000  1086.10
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d... -0.049000  1088.24
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-... -0.035000  1084.29
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,... -0.047000  1085.39
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,... -0.187500  1085.27
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  0.034500  1088.86
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  0.020000  1087.40
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  0.010000  1087.72
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  0.043085  1088.87
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-... -0.159000  1082.48
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha... -0.186000  1085.06
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2... -0.207000  1086.44
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1... -0.199000  1085.55
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,... -0.190000  1085.19
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d... -0.183500  1087.44
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina... -0.184000  1086.23
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy... -0.154000  1087.41
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy... -0.171500  1085.98
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,... -0.157000  1086.10
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d... -0.049000  1088.24
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-... -0.035000  1084.29
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,... -0.047000  1085.39
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,... -0.187500  1085.27
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  0.034500  1088.86
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  0.020000  1087.40
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  0.010000  1087.72
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  0.043085  1088.87
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-... -0.159000  1082.48
#
#                                                        iPOsy    nPOas  \
# catalyst_name
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  364.3460  1306.55
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  320.2800  1310.44
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  356.6200  1306.58
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  338.5586  1306.11
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  332.8368  1317.37
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  355.7629  1307.21
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  296.0611  1317.62
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  366.5389  1310.24
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  320.0554  1312.33
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  321.9825  1324.49
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  280.9149  1304.69
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  333.9214  1306.58
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  332.3749  1303.80
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  196.1110  1316.13
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  216.5108  1313.07
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  144.5405  1315.18
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  199.9616  1316.93
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  294.7768  1308.52
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  364.3460  1306.55
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  320.2800  1310.44
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  356.6200  1306.58
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  338.5586  1306.11
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  332.8368  1317.37
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  355.7629  1307.21
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  296.0611  1317.62
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  366.5389  1310.24
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  320.0554  1312.33
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  321.9825  1324.49
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  280.9149  1304.69
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  333.9214  1306.58
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  332.3749  1303.80
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  196.1110  1316.13
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  216.5108  1313.07
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  144.5405  1315.18
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  199.9616  1316.93
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  294.7768  1308.52
#
#                                                        iPOas        P  \
# catalyst_name
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  271.6062  2.54600
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  295.3595  2.54500
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  242.2277  2.54600
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  286.4410  2.54600
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  222.6765  2.53900
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  397.3333  2.54500
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  300.6142  2.54300
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  248.6693  2.54800
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  202.3039  2.54400
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  223.9890  2.53900
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  260.8236  2.55100
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...   92.5984  2.54800
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  212.5742  2.54700
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  257.1002  2.56200
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  257.3437  2.55400
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  255.7506  2.55300
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  184.6259  2.56344
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  252.6676  2.54400
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  271.6062  2.54600
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  295.3595  2.54500
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  242.2277  2.54600
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  286.4410  2.54600
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  222.6765  2.53900
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  397.3333  2.54500
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  300.6142  2.54300
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  248.6693  2.54800
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  202.3039  2.54400
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  223.9890  2.53900
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  260.8236  2.55100
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...   92.5984  2.54800
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  212.5742  2.54700
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  257.1002  2.56200
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  257.3437  2.55400
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  255.7506  2.55300
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  184.6259  2.56344
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  252.6676  2.54400
#
#                                                         PNMR
# catalyst_name
# (R)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  266.5125
# (R)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  266.1502
# (R)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  266.3224
# (R)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  266.1394
# (R)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  268.1404
# (R)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  266.1523
# (R)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  266.2896
# (R)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  269.8459
# (R)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  266.3457
# (R)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  268.9526
# (R)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  267.8360
# (R)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  267.9156
# (R)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  266.3803
# (R)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  270.4653
# (R)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  269.5145
# (R)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  269.7534
# (R)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  270.3919
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  271.2994
# (S)-2,2'-Dihydroxy-3,3'-diphenyl-1,1'-binaphtha...  266.5125
# (S)-3,3′-Bis(4-nitrophenyl)-1,1′-binaphthyl-2,2...  266.1502
# (S)-3,3'-Bis[4-(2,4,6-trimethylphenyl)phenyl]-1...  266.3224
# (S)-3,3′-Bis(4-chlorophenyl)-1,1′-binaphthyl-2,...  266.1394
# (S)-3,3'-Bis(4-diphenyl)-1,1'-binaphthyl 2,2'-d...  268.1404
# (S)-3,3′-Bis(4-trifluoromethylphenyl)-1,1′-bina...  266.1523
# (S)-3,3′-Bis(3,5-dinitrolphenyl)-1,1′-binaphthy...  266.2896
# (S)-3,3'-Bis(3,5-diphenyl)phenyl-1,1'-binaphthy...  269.8459
# (S)-3,3′-Bis[3,5-bis(trifluoromethyl)phenyl]-1,...  266.3457
# (S)-3,3-Bis(9-anthracenyl)-1,1-binaphthyl-2,2-d...  268.9526
# (S)-3,3'-Bis(9-phenanthryl)-1,1'-binaphthalene-...  267.8360
# (S)-3,3'-Bis(1-naphthalenyl)-1,1'-binaphthyl-2,...  267.9156
# (S)-3,3'-Bis(2-naphthalenyl)-1,1'-binaphthyl-2,...  266.3803
# (S)-3,3′-Bis(2,4,6-triisopropylphenyl)-1,1′-bin...  270.4653
# (S)-3,3′-Bis(2,4,6-trimethylphenyl)-1,1′-binaph...  269.5145
# (S)-3,3′-Bis(2,6-dimethylphenyl)-1,1′-binaphthy...  269.7534
# (S)-4-Hydroxy-2,6-bis(2,4,6-tricyclohexylphenyl...  270.3919
# (11bS)-2,6-Bis[3,5-bis(trifluoromethyl)phenyl]-...  271.2994
#
# [36 rows x 85 columns]

# %%
iminium_data = pd.read_excel('/Users/jlisd/Downloads/AI Chem/AI Chem/Holistic prediction of enantioselectivity in asymmetric catalysis.Supplementary Data.xlsx', sheet_name = 'iminiums')
iminium_data.rename(columns = {'imine': 'iminium_name', 'electronic energy difference (kcal/mol) ': 'electronic energy difference (kcal/mol)'}, inplace = True)
#removed space at the end of electronic energy
iminium_data.set_index('iminium_name', inplace = True)
iminium_data.drop(labels = ['Unnamed: 1'], axis = 1, inplace = True)
for i in range(1, 181):
    z_iminium_name = '(Z)-Iminium ' + str(i)
    e_iminium_name = '(E)-Iminium ' + str(i)
    iminium_data.loc[z_iminium_name, 'electronic energy difference (kcal/mol)'] = iminium_data.loc[e_iminium_name, 'electronic energy difference (kcal/mol)']
iminium_columns = list(iminium_data.columns)

# %%
iminium_data.head()
# Out:
#                    nNH      i NH      N  H (iminium)      C   SubL   SubS  \
# iminium_name
# (E)-Iminium 1  3474.83   97.5295 -0.426        0.442  0.487 -0.464 -0.697
# (Z)-Iminium 1  3491.05   82.0336 -0.430        0.424  0.526 -0.488 -0.687
# (E)-Iminium 2  3400.90  359.5285 -0.447        0.457  0.477 -0.466 -0.690
# (Z)-Iminium 2  3494.88   82.0612 -0.438        0.425  0.523 -0.503 -0.689
# (E)-Iminium 3  3196.55  910.2524 -0.419        0.469  0.420 -0.140 -0.690
#
#                   PG   PGL  PGB1  ...    SL  SB1   SB5    LL  LB1   LB5  \
# iminium_name                      ...
# (E)-Iminium 1  0.030  8.85  1.76  ...  3.59  1.7  2.12  4.61  1.7  7.04
# (Z)-Iminium 1  0.017  8.84  1.77  ...  3.59  1.7  2.13  4.77  1.7  7.17
# (E)-Iminium 2  0.031  8.81  1.75  ...  3.59  1.7  2.12  4.76  1.7  5.63
# (Z)-Iminium 2  0.022  8.85  1.76  ...  3.59  1.7  2.13  4.66  1.7  5.07
# (E)-Iminium 3  0.032  8.79  1.74  ...  3.59  1.7  2.12  7.09  1.7  7.45
#
#                HOMO (iminium)  LUMO (iminium)  Polarizability (iminium)  \
# iminium_name
# (E)-Iminium 1        -0.40205        -0.17518                    201.89
# (Z)-Iminium 1        -0.40330        -0.17332                    193.50
# (E)-Iminium 2        -0.40541        -0.17578                    164.07
# (Z)-Iminium 2        -0.40963        -0.17836                    160.51
# (E)-Iminium 3        -0.40169        -0.18157                    220.26
#
#                electronic energy difference (kcal/mol)
# iminium_name
# (E)-Iminium 1                                     1.62
# (Z)-Iminium 1                                     1.62
# (E)-Iminium 2                                     1.86
# (Z)-Iminium 2                                     1.86
# (E)-Iminium 3                                     0.69
#
# [5 rows x 21 columns]

# %%
class Reaction():
    
    def __init__(self, name, entry, catalyst, nucleophile, substrate, solvent, iminium_type, iminium, majorenantiomer, minorenantiomer, ee, G):
        self.name = name
        self.entry = entry
        self.catalyst = catalyst
        self.nucleophile = nucleophile
        self.substrate = substrate
        self.solvent = solvent
        self.iminium_type = iminium_type
        self.iminium = iminium
        self.majorenantiomer = majorenantiomer
        self.minorenantiomer = minorenantiomer
        self.ee = ee
        self.G = G
            
        self.solvent_properties = dict()
        for column in solvent_columns:
            self.solvent_properties[column] = solvent_data.loc[solvent, column]
            
        self.catalyst_properties = dict()
        for column in catalyst_columns:
            self.catalyst_properties[column] = catalyst_data.loc[catalyst, column]
            
        self.nucleophile_properties = dict()
        for column in nucleophile_columns:
            self.nucleophile_properties[column] = nucleophile_data.loc[nucleophile, column]
        
        self.e_iminium = '(E)-' + str(iminium)
        self.z_iminium = '(Z)-' + str(iminium)
        
        self.e_iminium_properties = dict()
        self.z_iminium_properties = dict()
        for column in iminium_columns:
            self.e_iminium_properties[column] = iminium_data.loc[self.e_iminium, column]
            self.z_iminium_properties[column] = iminium_data.loc[self.z_iminium, column]
            
        
            
    def __repr__(self):
        return "Reaction - {}".format(self.name)
        #iminium stuff

# %%
reactions = dict()

def process_data(reaction_number, reaction, iminium_type, sheetname = None):
    reaction_file = '/Users/jlisd/Downloads/AI Chem/AI Chem/reaction info 5-23/' + str(reaction_number) + ' ' + reaction + '.xlsx'
    if sheetname == None:
        data = pd.read_excel(reaction_file)
    else:
        data = pd.read_excel(reaction_file, sheet_name = sheetname)
        
    data.set_index('entry', inplace = True)
    
    entries = len(data)
    for entry in range(1, entries + 1):
        if sheetname == None:
            reaction_name = reaction + ' ' + str(entry)
        else:
            reaction_name = reaction + ' ' + sheetname + ' ' + str(entry)
        
        
        reactions[reaction_name] = Reaction(reaction_name, 
                                            entry,
                                            data.loc[entry, 'Catalyst'],
                                            data.loc[entry, 'Nucleophile'],
                                            data.loc[entry, 'Substrate'],
                                            data.loc[entry, 'Solvent'],
                                            iminium_type,
                                            data.loc[entry, 'Iminium'],
                                            data.loc[entry, 'Major Enantiomer'],
                                            data.loc[entry, 'Minor Enantiomer'],
                                            data.loc[entry, 'ee'],
                                            data.loc[entry, 'ΔΔG‡'])

# %%
process_data(1, 'Addition of Alcohols', 'E', 'Scope')
process_data(2, 'Addition of thiols', 'E', 'Catalyst & solvent screening da')
process_data(2, 'Addition of thiols', 'E', 'Effect of catalyst loading')
process_data(2, 'Addition of thiols', 'E', 'Imine scope')
process_data(2, 'Addition of thiols', 'E', 'Thiol scope')
process_data(3, 'Hydrophosphonylation of imines', 'E', 'Catalyst screening data')
process_data(3, 'Hydrophosphonylation of imines', 'E', 'Scope')
process_data(4, 'Addition of diazomethylphosphonates', 'E', "Optimization of catalyst and re")
process_data(4, 'Addition of diazomethylphosphonates', 'E', "Imine scope")
process_data(5, 'Addition of diazoacetamides', 'E', 'Catalyst screening data')
process_data(5, 'Addition of diazoacetamides', 'E', 'Solvent screening data')
process_data(5, 'Addition of diazoacetamides', 'E', 'Substrate(s) scope')
process_data(6, 'Strecker Reaction (with aldimines)', 'E', 'Catalyst screening data')
process_data(6, 'Strecker Reaction (with aldimines)', 'E', 'Solvent screening data')
process_data(6, 'Strecker Reaction (with aldimines)', 'E', 'Imine scope')
process_data(7, 'Peroxidation of imines', 'E', 'Catalyst screening data')
process_data(7, 'Peroxidation of imines', 'E', 'Solvent screening data')
process_data(7, 'Peroxidation of imines', 'E', 'Substrate(s) scope')
process_data(8, 'Transfer Hydrogenation of b,g-Alkynyl a-Imino Esters', 'E', 'Catalyst screening and reaction')
process_data(8, 'Transfer Hydrogenation of b,g-Alkynyl a-Imino Esters', 'E', 'Scope')
process_data(9, 'Transfer Hydrogenation of Enamides', 'E', 'Scope')
process_data(10, 'Transfer Hydrogenation of N-aryl imines (List)', 'Z', 'Catalyst screening data')
process_data(10, 'Transfer Hydrogenation of N-aryl imines (List)', 'Z', 'Imine scope')
process_data(11, 'Transfer Hydrogenation of N-aryl imines (Rueping)', 'Z', 'Catalyst screening data')
process_data(11, 'Transfer Hydrogenation of N-aryl imines (Rueping)', 'Z', 'Solvent screening data')
process_data(11, 'Transfer Hydrogenation of N-aryl imines (Rueping)', 'Z', 'Imine scope')
process_data(12, 'Reductive amination of N-aryl imines (Macmillan)', 'Z', 'Reaction optimization')
process_data(13, 'Transfer Hydrogenation of trifluoromethyl ketimines', 'Z', 'Benzothiazoline screening data')
process_data(13, 'Transfer Hydrogenation of trifluoromethyl ketimines', 'Z', 'Imine scope')
process_data(14, 'Transfer Hydrogenation of N-aryl imines by benzothiazoline', 'Z', 'Catalyst screening data')
process_data(14, 'Transfer Hydrogenation of N-aryl imines by benzothiazoline', 'Z', 'Benzothiazoline screening data')
process_data(14, 'Transfer Hydrogenation of N-aryl imines by benzothiazoline', 'Z', 'Imine scope')
process_data(15, 'Reductive amination of aliphatic ketones by benzothiazoline', 'Z', 'Catalyst screening data')
process_data(15, 'Reductive amination of aliphatic ketones by benzothiazoline', 'Z', 'Imine scope')
process_data(16, 'Transfer Hydrogenation of ethyl ketimines', 'Z', 'Benzothiazoline screening data')
process_data(16, 'Transfer Hydrogenation of ethyl ketimines', 'Z', 'Scope 1 benzothiazoline')
process_data(16, 'Transfer Hydrogenation of ethyl ketimines', 'Z', 'Scope 2 dihydropyridine')
process_data(17, 'Strecker Reaction (with ketimines)', 'Z', 'Catalyst screening data')
process_data(17, 'Strecker Reaction (with ketimines)', 'Z', 'Solvent data')
process_data(17, 'Strecker Reaction (with ketimines)', 'Z', 'Imine scope')
#process_data(18, 'Addition of enecarbamates to benzoyl imines')
#process_data(19, 'Hydrogenation of fluorinated alkynyl ketimines')
#process_data(20, 'Addition of thiols to imines (Denmark)')

# %%
print(len(reactions))
# Out:
# 381

# %%
catalyst = pd.DataFrame(columns = ['Reaction'] + catalyst_columns)
catalyst.set_index('Reaction', inplace = True)

for reaction in reactions:
    for column in catalyst_columns:
        catalyst.loc[reaction, column] = reactions[reaction].catalyst_properties[column]
        
#first column is numerical

# %%
catalyst.head()
# Out:
#                                Ar group    arhs    alhs     aavg       b  \
# Reaction
# Addition of Alcohols Scope 1  9-Anthryl  78.854  78.853  78.8535  55.161
# Addition of Alcohols Scope 2  9-Anthryl  78.854  78.853  78.8535  55.161
# Addition of Alcohols Scope 3  9-Anthryl  78.854  78.853  78.8535  55.161
# Addition of Alcohols Scope 4  9-Anthryl  78.854  78.853  78.8535  55.161
# Addition of Alcohols Scope 5  9-Anthryl  78.854  78.853  78.8535  55.161
#
#                              AREA(q) sin(AREA) Lwhole R B1whole R B5whole R  \
# Reaction
# Addition of Alcohols Scope 1      61 -0.966118     6.94      1.73      5.72
# Addition of Alcohols Scope 2      61 -0.966118     6.94      1.73      5.72
# Addition of Alcohols Scope 3      61 -0.966118     6.94      1.73      5.72
# Addition of Alcohols Scope 4      61 -0.966118     6.94      1.73      5.72
# Addition of Alcohols Scope 5      61 -0.966118     6.94      1.73      5.72
#
#                               ...   C3 A   C4 A   C5 A   C6 A    nPOsy  \
# Reaction                      ...
# Addition of Alcohols Scope 1  ... -0.054 -0.162 -0.059 -0.049  1088.24
# Addition of Alcohols Scope 2  ... -0.054 -0.162 -0.059 -0.049  1088.24
# Addition of Alcohols Scope 3  ... -0.054 -0.162 -0.059 -0.049  1088.24
# Addition of Alcohols Scope 4  ... -0.054 -0.162 -0.059 -0.049  1088.24
# Addition of Alcohols Scope 5  ... -0.054 -0.162 -0.059 -0.049  1088.24
#
#                                 iPOsy    nPOas    iPOas      P     PNMR
# Reaction
# Addition of Alcohols Scope 1  321.983  1324.49  223.989  2.539  268.953
# Addition of Alcohols Scope 2  321.983  1324.49  223.989  2.539  268.953
# Addition of Alcohols Scope 3  321.983  1324.49  223.989  2.539  268.953
# Addition of Alcohols Scope 4  321.983  1324.49  223.989  2.539  268.953
# Addition of Alcohols Scope 5  321.983  1324.49  223.989  2.539  268.953
#
# [5 rows x 85 columns]

# %%
nucleophile = pd.DataFrame(columns = ['Reaction'] + nucleophile_columns)
nucleophile.set_index('Reaction', inplace = True)

for reaction in reactions:
    for column in nucleophile_columns:
        nucleophile.loc[reaction, column] = reactions[reaction].nucleophile_properties[column]
        
#first column is numerical

# %%
nucleophile.head()
# Out:
#                                   nucleophile H (nucleophile)      X     Nu  \
# Reaction
# Addition of Alcohols Scope 1         methanol           0.458 -0.707 -0.707
# Addition of Alcohols Scope 2          ethanol           0.464 -0.717 -0.717
# Addition of Alcohols Scope 3      isopropanol           0.461 -0.717 -0.717
# Addition of Alcohols Scope 4     tert-butanol           0.459 -0.722 -0.722
# Addition of Alcohols Scope 5  2-chloroethanol           0.471 -0.704 -0.704
#
#                                   nXH      iXH HOMO (nucleophile)  \
# Reaction
# Addition of Alcohols Scope 1   3899.4  40.1897           -0.35328
# Addition of Alcohols Scope 2  3893.54  39.6036           -0.34808
# Addition of Alcohols Scope 3   3877.1  28.7764           -0.34588
# Addition of Alcohols Scope 4  3859.15  22.2253           -0.34415
# Addition of Alcohols Scope 5   3851.9  43.4805            -0.3582
#
#                              LUMO (nucleophile) Polarizability (nucleophile)  \
# Reaction
# Addition of Alcohols Scope 1             0.0626                        18.27
# Addition of Alcohols Scope 2            0.06264                        30.23
# Addition of Alcohols Scope 3            0.05777                        42.01
# Addition of Alcohols Scope 4            0.05141                        53.61
# Addition of Alcohols Scope 5            0.05955                        40.75
#
#                                  L    B1    B5 bond distance H-X H-X-Nu  \
# Reaction
# Addition of Alcohols Scope 1  3.99   1.4  3.17              0.96    180
# Addition of Alcohols Scope 2  5.03   1.2  3.41              0.96    180
# Addition of Alcohols Scope 3  5.03  1.13  4.45              0.96    180
# Addition of Alcohols Scope 4  5.03  1.44  4.44              0.96    180
# Addition of Alcohols Scope 5  3.98   1.4  4.44              0.96    180
#
#                              H-X-CNu
# Reaction
# Addition of Alcohols Scope 1     180
# Addition of Alcohols Scope 2     180
# Addition of Alcohols Scope 3     180
# Addition of Alcohols Scope 4     180
# Addition of Alcohols Scope 5     180

# %%
solvent = pd.DataFrame(columns = ['Reaction'] + solvent_columns)
solvent.set_index('Reaction', inplace = True)

for reaction in reactions:
    for column in solvent_columns:
        solvent.loc[reaction, column] = reactions[reaction].solvent_properties[column]
        
#first column is numerical

# %%
solvent.head()
# Out:
#                                     solvent First Zagreb  \
# Reaction
# Addition of Alcohols Scope 1  ethyl acetate           20
# Addition of Alcohols Scope 2  ethyl acetate           20
# Addition of Alcohols Scope 3  ethyl acetate           20
# Addition of Alcohols Scope 4  ethyl acetate           20
# Addition of Alcohols Scope 5  ethyl acetate           20
#
#                              First Zagreb index by valence vertex degrees  \
# Reaction
# Addition of Alcohols Scope 1                                           94
# Addition of Alcohols Scope 2                                           94
# Addition of Alcohols Scope 3                                           94
# Addition of Alcohols Scope 4                                           94
# Addition of Alcohols Scope 5                                           94
#
#                              Second Zagreb  \
# Reaction
# Addition of Alcohols Scope 1            18
# Addition of Alcohols Scope 2            18
# Addition of Alcohols Scope 3            18
# Addition of Alcohols Scope 4            18
# Addition of Alcohols Scope 5            18
#
#                              Second Zagreb index by valence vertex degrees  \
# Reaction
# Addition of Alcohols Scope 1                                            66
# Addition of Alcohols Scope 2                                            66
# Addition of Alcohols Scope 3                                            66
# Addition of Alcohols Scope 4                                            66
# Addition of Alcohols Scope 5                                            66
#
#                              Polarity Narumi Simple Topological  \
# Reaction
# Addition of Alcohols Scope 1        3                     2.485
# Addition of Alcohols Scope 2        3                     2.485
# Addition of Alcohols Scope 3        3                     2.485
# Addition of Alcohols Scope 4        3                     2.485
# Addition of Alcohols Scope 5        3                     2.485
#
#                              Narumi Harmonic Topological  \
# Reaction
# Addition of Alcohols Scope 1                       1.385
# Addition of Alcohols Scope 2                       1.385
# Addition of Alcohols Scope 3                       1.385
# Addition of Alcohols Scope 4                       1.385
# Addition of Alcohols Scope 5                       1.385
#
#                              Narumi Geometric Topological  \
# Reaction
# Addition of Alcohols Scope 1                        1.513
# Addition of Alcohols Scope 2                        1.513
# Addition of Alcohols Scope 3                        1.513
# Addition of Alcohols Scope 4                        1.513
# Addition of Alcohols Scope 5                        1.513
#
#                              Total structure connectivity  ...  CLOGP    MR  \
# Reaction                                                   ...
# Addition of Alcohols Scope 1                        0.289  ...  0.711  22.2
# Addition of Alcohols Scope 2                        0.289  ...  0.711  22.2
# Addition of Alcohols Scope 3                        0.289  ...  0.711  22.2
# Addition of Alcohols Scope 4                        0.289  ...  0.711  22.2
# Addition of Alcohols Scope 5                        0.289  ...  0.711  22.2
#
#                                  CMR    RMM Density no. of H bond donor  \
# Reaction
# Addition of Alcohols Scope 1  2.2214  88.11   0.902                   0
# Addition of Alcohols Scope 2  2.2214  88.11   0.902                   0
# Addition of Alcohols Scope 3  2.2214  88.11   0.902                   0
# Addition of Alcohols Scope 4  2.2214  88.11   0.902                   0
# Addition of Alcohols Scope 5  2.2214  88.11   0.902                   0
#
#                              no. H bond acceptor Polarizability (solvent)  \
# Reaction
# Addition of Alcohols Scope 1                   2                     54.4
# Addition of Alcohols Scope 2                   2                     54.4
# Addition of Alcohols Scope 3                   2                     54.4
# Addition of Alcohols Scope 4                   2                     54.4
# Addition of Alcohols Scope 5                   2                     54.4
#
#                              HOMO (solvent) LUMO (solvent)
# Reaction
# Addition of Alcohols Scope 1       -0.35344        0.05588
# Addition of Alcohols Scope 2       -0.35344        0.05588
# Addition of Alcohols Scope 3       -0.35344        0.05588
# Addition of Alcohols Scope 4       -0.35344        0.05588
# Addition of Alcohols Scope 5       -0.35344        0.05588
#
# [5 rows x 160 columns]

# %%
iminium = pd.DataFrame(columns = ['Reaction', "iminium_type"] + iminium_columns)
iminium.set_index('Reaction', inplace = True)

for reaction in reactions:
    if reactions[reaction].iminium_type == 'E':
        iminium.loc[reaction, "iminium_type"] = 'E'
        for column in iminium_columns:
            iminium.loc[reaction, column] = reactions[reaction].e_iminium_properties[column]
    elif reactions[reaction].iminium_type == 'Z':
        iminium.loc[reaction, "iminium_type"] = 'Z'
        for column in iminium_columns:
            iminium.loc[reaction, column] = reactions[reaction].z_iminium_properties[column]

# %%
iminium.head()
# Out:
#                              iminium_type      nNH     i NH      N  \
# Reaction
# Addition of Alcohols Scope 1            E  3569.31  83.7481 -0.533
# Addition of Alcohols Scope 2            E  3569.31  83.7481 -0.533
# Addition of Alcohols Scope 3            E  3569.31  83.7481 -0.533
# Addition of Alcohols Scope 4            E  3569.31  83.7481 -0.533
# Addition of Alcohols Scope 5            E  3569.31  83.7481 -0.533
#
#                              H (iminium)      C SubL   SubS    PG   PGL  ...  \
# Reaction                                                                 ...
# Addition of Alcohols Scope 1       0.427  0.306 -0.2  0.255  0.69  6.63  ...
# Addition of Alcohols Scope 2       0.427  0.306 -0.2  0.255  0.69  6.63  ...
# Addition of Alcohols Scope 3       0.427  0.306 -0.2  0.255  0.69  6.63  ...
# Addition of Alcohols Scope 4       0.427  0.306 -0.2  0.255  0.69  6.63  ...
# Addition of Alcohols Scope 5       0.427  0.306 -0.2  0.255  0.69  6.63  ...
#
#                                 SL   SB1   SB5    LL  LB1   LB5  \
# Reaction
# Addition of Alcohols Scope 1  2.58  1.09  1.09  6.76  1.7  3.39
# Addition of Alcohols Scope 2  2.58  1.09  1.09  6.76  1.7  3.39
# Addition of Alcohols Scope 3  2.58  1.09  1.09  6.76  1.7  3.39
# Addition of Alcohols Scope 4  2.58  1.09  1.09  6.76  1.7  3.39
# Addition of Alcohols Scope 5  2.58  1.09  1.09  6.76  1.7  3.39
#
#                              HOMO (iminium) LUMO (iminium)  \
# Reaction
# Addition of Alcohols Scope 1       -0.44273       -0.23633
# Addition of Alcohols Scope 2       -0.44273       -0.23633
# Addition of Alcohols Scope 3       -0.44273       -0.23633
# Addition of Alcohols Scope 4       -0.44273       -0.23633
# Addition of Alcohols Scope 5       -0.44273       -0.23633
#
#                              Polarizability (iminium)  \
# Reaction
# Addition of Alcohols Scope 1                   180.99
# Addition of Alcohols Scope 2                   180.99
# Addition of Alcohols Scope 3                   180.99
# Addition of Alcohols Scope 4                   180.99
# Addition of Alcohols Scope 5                   180.99
#
#                              electronic energy difference (kcal/mol)
# Reaction
# Addition of Alcohols Scope 1                                    6.67
# Addition of Alcohols Scope 2                                    6.67
# Addition of Alcohols Scope 3                                    6.67
# Addition of Alcohols Scope 4                                    6.67
# Addition of Alcohols Scope 5                                    6.67
#
# [5 rows x 22 columns]

# %%
ee = pd.DataFrame(columns = ['Reaction', 'ee'])
ee.set_index('Reaction', inplace = True)

for reaction in reactions:
    ee.loc[reaction, 'ee'] = reactions[reaction].ee

# %%
Y = pd.DataFrame(columns = ['Reaction', 'ΔΔG‡'])
Y.set_index('Reaction', inplace = True)

for reaction in reactions:
    Y.loc[reaction, 'ΔΔG‡'] = reactions[reaction].G

# %%
print(catalyst.shape, nucleophile.shape, solvent.shape, iminium.shape, ee.shape)
# Out:
# (381, 85) (381, 15) (381, 160) (381, 22) (381, 1)

# %%
X_iminium = pd.concat([catalyst.drop(['Ar group'], axis = 1), 
               nucleophile.drop(['nucleophile'], axis = 1), 
               solvent.drop(['solvent'], axis = 1), 
               iminium.drop(['iminium_type'], axis = 1)], axis = 1)
X_iminium.shape
# Out:
# (381, 278)

# %%
X_iminium
# Out:
#                                                      arhs    alhs     aavg  \
# Reaction
# Addition of Alcohols Scope 1                       78.854  78.853  78.8535
# Addition of Alcohols Scope 2                       78.854  78.853  78.8535
# Addition of Alcohols Scope 3                       78.854  78.853  78.8535
# Addition of Alcohols Scope 4                       78.854  78.853  78.8535
# Addition of Alcohols Scope 5                       78.854  78.853  78.8535
# ...                                                   ...     ...      ...
# Strecker Reaction (with ketimines) Imine scope 6   78.854  78.853  78.8535
# Strecker Reaction (with ketimines) Imine scope 7   78.854  78.853  78.8535
# Strecker Reaction (with ketimines) Imine scope 8   78.854  78.853  78.8535
# Strecker Reaction (with ketimines) Imine scope 9   78.854  78.853  78.8535
# Strecker Reaction (with ketimines) Imine scope 10  78.854  78.853  78.8535
#
#                                                         b AREA(q) sin(AREA)  \
# Reaction
# Addition of Alcohols Scope 1                       55.161      61 -0.966118
# Addition of Alcohols Scope 2                       55.161      61 -0.966118
# Addition of Alcohols Scope 3                       55.161      61 -0.966118
# Addition of Alcohols Scope 4                       55.161      61 -0.966118
# Addition of Alcohols Scope 5                       55.161      61 -0.966118
# ...                                                   ...     ...       ...
# Strecker Reaction (with ketimines) Imine scope 6   55.161      61 -0.966118
# Strecker Reaction (with ketimines) Imine scope 7   55.161      61 -0.966118
# Strecker Reaction (with ketimines) Imine scope 8   55.161      61 -0.966118
# Strecker Reaction (with ketimines) Imine scope 9   55.161      61 -0.966118
# Strecker Reaction (with ketimines) Imine scope 10  55.161      61 -0.966118
#
#                                                   Lwhole R B1whole R  \
# Reaction
# Addition of Alcohols Scope 1                          6.94      1.73
# Addition of Alcohols Scope 2                          6.94      1.73
# Addition of Alcohols Scope 3                          6.94      1.73
# Addition of Alcohols Scope 4                          6.94      1.73
# Addition of Alcohols Scope 5                          6.94      1.73
# ...                                                    ...       ...
# Strecker Reaction (with ketimines) Imine scope 6      6.94      1.73
# Strecker Reaction (with ketimines) Imine scope 7      6.94      1.73
# Strecker Reaction (with ketimines) Imine scope 8      6.94      1.73
# Strecker Reaction (with ketimines) Imine scope 9      6.94      1.73
# Strecker Reaction (with ketimines) Imine scope 10     6.94      1.73
#
#                                                   B5whole R  L2 R  ...    SL  \
# Reaction                                                           ...
# Addition of Alcohols Scope 1                           5.72  9.12  ...  2.58
# Addition of Alcohols Scope 2                           5.72  9.12  ...  2.58
# Addition of Alcohols Scope 3                           5.72  9.12  ...  2.58
# Addition of Alcohols Scope 4                           5.72  9.12  ...  2.58
# Addition of Alcohols Scope 5                           5.72  9.12  ...  2.58
# ...                                                     ...   ...  ...   ...
# Strecker Reaction (with ketimines) Imine scope 6       5.72  9.12  ...  3.59
# Strecker Reaction (with ketimines) Imine scope 7       5.72  9.12  ...  3.59
# Strecker Reaction (with ketimines) Imine scope 8       5.72  9.12  ...  3.59
# Strecker Reaction (with ketimines) Imine scope 9       5.72  9.12  ...  3.59
# Strecker Reaction (with ketimines) Imine scope 10      5.72  9.12  ...   3.6
#
#                                                     SB1   SB5     LL   LB1  \
# Reaction
# Addition of Alcohols Scope 1                       1.09  1.09   6.76   1.7
# Addition of Alcohols Scope 2                       1.09  1.09   6.76   1.7
# Addition of Alcohols Scope 3                       1.09  1.09   6.76   1.7
# Addition of Alcohols Scope 4                       1.09  1.09   6.76   1.7
# Addition of Alcohols Scope 5                       1.09  1.09   6.76   1.7
# ...                                                 ...   ...    ...   ...
# Strecker Reaction (with ketimines) Imine scope 6    1.7  2.12  11.09  1.96
# Strecker Reaction (with ketimines) Imine scope 7    1.7  2.12  11.09  1.97
# Strecker Reaction (with ketimines) Imine scope 8    1.7  2.12   8.36  1.73
# Strecker Reaction (with ketimines) Imine scope 9    1.7  2.12    8.9   1.7
# Strecker Reaction (with ketimines) Imine scope 10   1.7  2.12   8.89  1.74
#
#                                                     LB5 HOMO (iminium)  \
# Reaction
# Addition of Alcohols Scope 1                       3.39       -0.44273
# Addition of Alcohols Scope 2                       3.39       -0.44273
# Addition of Alcohols Scope 3                       3.39       -0.44273
# Addition of Alcohols Scope 4                       3.39       -0.44273
# Addition of Alcohols Scope 5                       3.39       -0.44273
# ...                                                 ...            ...
# Strecker Reaction (with ketimines) Imine scope 6   3.29       -0.38303
# Strecker Reaction (with ketimines) Imine scope 7   3.29       -0.39109
# Strecker Reaction (with ketimines) Imine scope 8    3.3       -0.38516
# Strecker Reaction (with ketimines) Imine scope 9   4.51       -0.38351
# Strecker Reaction (with ketimines) Imine scope 10  3.29       -0.38261
#
#                                                   LUMO (iminium)  \
# Reaction
# Addition of Alcohols Scope 1                            -0.23633
# Addition of Alcohols Scope 2                            -0.23633
# Addition of Alcohols Scope 3                            -0.23633
# Addition of Alcohols Scope 4                            -0.23633
# Addition of Alcohols Scope 5                            -0.23633
# ...                                                          ...
# Strecker Reaction (with ketimines) Imine scope 6        -0.18662
# Strecker Reaction (with ketimines) Imine scope 7        -0.19325
# Strecker Reaction (with ketimines) Imine scope 8        -0.19602
# Strecker Reaction (with ketimines) Imine scope 9        -0.18643
# Strecker Reaction (with ketimines) Imine scope 10       -0.18127
#
#                                                   Polarizability (iminium)  \
# Reaction
# Addition of Alcohols Scope 1                                        180.99
# Addition of Alcohols Scope 2                                        180.99
# Addition of Alcohols Scope 3                                        180.99
# Addition of Alcohols Scope 4                                        180.99
# Addition of Alcohols Scope 5                                        180.99
# ...                                                                    ...
# Strecker Reaction (with ketimines) Imine scope 6                    288.98
# Strecker Reaction (with ketimines) Imine scope 7                    293.53
# Strecker Reaction (with ketimines) Imine scope 8                    223.73
# Strecker Reaction (with ketimines) Imine scope 9                    257.65
# Strecker Reaction (with ketimines) Imine scope 10                   225.51
#
#                                                   electronic energy difference (kcal/mol)
# Reaction
# Addition of Alcohols Scope 1                                                         6.67
# Addition of Alcohols Scope 2                                                         6.67
# Addition of Alcohols Scope 3                                                         6.67
# Addition of Alcohols Scope 4                                                         6.67
# Addition of Alcohols Scope 5                                                         6.67
# ...                                                                                   ...
# Strecker Reaction (with ketimines) Imine scope 6                                     1.14
# Strecker Reaction (with ketimines) Imine scope 7                                     1.22
# Strecker Reaction (with ketimines) Imine scope 8                                     2.41
# Strecker Reaction (with ketimines) Imine scope 9                                     1.71
# Strecker Reaction (with ketimines) Imine scope 10                                     1.2
#
# [381 rows x 278 columns]

# %%
#no iminium features
X_no_iminium = pd.concat([catalyst.drop(['Ar group'], axis = 1), 
               nucleophile.drop(['nucleophile'], axis = 1), 
               solvent.drop(['solvent'], axis = 1)], axis = 1)
X_no_iminium.shape
# Out:
# (381, 257)

# %%
X_no_nucleophile = pd.concat([catalyst.drop(['Ar group'], axis = 1), 
                   solvent.drop(['solvent'], axis = 1)], axis = 1)
X_no_nucleophile.shape
# Out:
# (381, 243)

# %%
for reaction in reactions:
    if iminium.loc[reaction, 'iminium_type'] == 'Z':
        Y.loc[reaction, 'ΔΔG‡'] = Y.loc[reaction, 'ΔΔG‡'] * (-1)

# %%
Y
# Out:
#                                                        ΔΔG‡
# Reaction
# Addition of Alcohols Scope 1                        2.05829
# Addition of Alcohols Scope 2                        1.74348
# Addition of Alcohols Scope 3                        1.62926
# Addition of Alcohols Scope 4                        1.88181
# Addition of Alcohols Scope 5                        1.88181
# ...                                                     ...
# Strecker Reaction (with ketimines) Imine scope 6  -0.840427
# Strecker Reaction (with ketimines) Imine scope 7   -1.01725
# Strecker Reaction (with ketimines) Imine scope 8  -0.767712
# Strecker Reaction (with ketimines) Imine scope 9  -0.641814
# Strecker Reaction (with ketimines) Imine scope 10 -0.585967
#
# [381 rows x 1 columns]

# %% [markdown]
# ###############################################################################################################################
#
# Reactions 18 - 20
#
# ###############################################################################################################################

# %%
#out of sample
X_oos = pd.read_excel('X_oos.xlsx', index = 'Reaction')
X_oos_iminium = pd.read_excel('X_oos_iminium.xlsx', index = Reaction)
Y_oos = pd.read_excel('Y_oos.xlsx', index = 'Reaction')

X_oos.set_index('Reaction', inplace = True)
X_oos_iminium.set_index('Reaction', inplace = True)
Y_oos.set_index('Reaction', inplace = True)

# %%
#X_oos_iminium = pd.concat([X_oos, iminium_oos.drop(['iminium_type'], axis = 1)], axis = 1)

# %%
#X_oos_iminium.to_excel('X_oos_iminium.xlsx')

# %% [markdown]
# ###############################################################################################################################
#
# End of Data Processing
#
# ###############################################################################################################################

# %%
random_state = random.seed(datetime.now())
test_size = 0.5
X = X_iminium

# %%
scaler = StandardScaler()
X_total = pd.concat([X_iminium, X_oos_iminium])
X_total_scaled = scaler.fit_transform(X_total)
X_total_scaled = pd.DataFrame(X_total_scaled, columns = list(X_total.columns), index = list(X_total.index))

X_scaled = X_total_scaled.iloc[:381, :]
X_oos_scaled = X_total_scaled.iloc[381:, :]

# %%
forest = RandomForestRegressor()
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size = test_size, random_state = random_state)

forest.fit(X_train, Y_train.reset_index().drop('Reaction', axis = 1).values.ravel())
Y_pred = forest.predict(X_test)

results = pd.concat([Y_test.reset_index(), pd.DataFrame(Y_pred)], axis = 1)
results.set_index('Reaction', inplace = True)
results.columns = ['Actual', 'Predicted']

print('MSE: ' + str(mean_squared_error(Y_test, Y_pred)))
print('r^2: ' + str(r2_score(Y_test, Y_pred)))
results.head()

Y_train_pred = forest.predict(X_train)
train_results = pd.concat([Y_train.reset_index(), pd.DataFrame(Y_train_pred)], axis = 1)
train_results.set_index('Reaction', inplace = True)
train_results.columns = ['Actual', 'Predicted']
train_results

all_results = pd.concat([train_results, results])
all_results
print('Total r^2 score: ' + str(r2_score(all_results['Actual'], all_results['Predicted'])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-64175bd99d7f> in <module>
#       1 forest = RandomForestRegressor()
# ----> 2 X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y_scaled, test_size = test_size, random_state = random_state)
#       3
#       4 forest.fit(X_train, Y_train.ravel())
#       5 Y_pred = forest.predict(X_test)
#
# NameError: name 'X_scaled' is not defined

# %% [markdown]
# ###############################################################################################################################
#
# Run model 100 times
#
# ###############################################################################################################################

# %%
def run_random_forest(iterations):
    scores = pd.DataFrame(columns = ['iteration', 'MSE', 'test r^2', 'train r^2', 'total r^2'])
    #scores.set_index('iteration', inplace = True)
    for i in range(iterations):
        #develop model & scores
        forest = RandomForestRegressor()
        X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_size, random_state = random_state)

        forest.fit(X_train.reset_index().drop(['Reaction'], axis = 1), Y_train.reset_index().drop('Reaction', axis = 1).values.ravel())
        
        #evaluating performance
        Y_pred = forest.predict(X_test.reset_index().drop(['Reaction'], axis = 1))

        results = pd.concat([Y_test.reset_index(), pd.DataFrame(Y_pred)], axis = 1)
        results.set_index('Reaction', inplace = True)
        results.columns = ['Actual', 'Predicted']

        Y_train_pred = forest.predict(X_train.reset_index().drop(['Reaction'], axis = 1))
        train_results = pd.concat([Y_train.reset_index(), pd.DataFrame(Y_train_pred)], axis = 1)
        train_results.set_index('Reaction', inplace = True)
        train_results.columns = ['Actual', 'Predicted']
        
        all_results = pd.concat([train_results, results])
        
        scores = scores.append({'iteration': str(i+1),
                    'MSE': mean_squared_error(Y_test, Y_pred),
                    'test r^2': r2_score(Y_test, Y_pred),
                    'train r^2': r2_score(train_results['Actual'], train_results['Predicted']),
                    'total r^2': r2_score(all_results['Actual'], all_results['Predicted'])}, ignore_index = True)
        
        #evaluating most important features
        features = pd.concat([pd.DataFrame(X.columns), pd.DataFrame(forest.feature_importances_)], axis = 1)
        features.columns = ['Feature', 'Importance']
        features.set_index('Feature', inplace = True)
        
        if i == 0:
            total_features = features.sort_values(by = ['Importance'], ascending = False)
        else:
            for feature in total_features.index:
                total_features.loc[feature, 'Importance'] += features.loc[feature, 'Importance']
    
    #add average for each row
    averages = pd.DataFrame(scores.mean(axis = 0)).T
    scores = scores.append({'iteration': 'average',
                           'MSE': averages.iloc[0,1],
                           'test r^2': averages.iloc[0,2],
                        'train r^2': averages.iloc[0,3],
                           'total r^2': averages.iloc[0,4]}, ignore_index = True)
    scores.set_index('iteration')
    
    #which stage each important feature is in
    for feature in total_features.index:
        if feature in solvent_columns:
            total_features.loc[feature, 'type'] = 'solvent'
        elif feature in nucleophile_columns:
            total_features.loc[feature, 'type'] = 'nucleophile'
        elif feature in catalyst_columns:
            total_features.loc[feature, 'type'] = 'catalyst'
        elif feature in iminium_columns:
            total_features.loc[feature, 'type'] = 'iminium'

    total_features = total_features[['type', 'Importance']]
    total_features = total_features.sort_values(by = ['Importance'], ascending = False)
    
    return scores, total_features

# %%
results, features = run_random_forest(100)
print(results)
print(results.std())
# Out:
#     iteration       MSE  test r^2  train r^2  total r^2
# 0           1  0.201586  0.938996   0.987661   0.961069
# 1           2  0.233669  0.916791   0.986435   0.954094
# 2           3  0.182315  0.940014   0.988915   0.964353
# 3           4  0.236281  0.922243   0.989975   0.955950
# 4           5  0.205130  0.932291   0.986963   0.959577
# ..        ...       ...       ...        ...        ...
# 96         97  0.207554  0.925535   0.989007   0.959795
# 97         98  0.218856  0.925468   0.988114   0.957706
# 98         99  0.211587  0.929357   0.986415   0.958170
# 99        100  0.197893  0.928157   0.988380   0.960953
# 100   average  0.222441  0.926280   0.987579   0.957040
#
# [101 rows x 5 columns]
# MSE          0.034544
# test r^2     0.011817
# train r^2    0.001860
# total r^2    0.005459
# dtype: float64

# %% [markdown]
# ###############################################################################################################################
#
# Run standardized model 100 times
#
# ###############################################################################################################################

# %%
def run_random_forest_standard(iterations):
    scores = pd.DataFrame(columns = ['iteration', 'MSE', 'r^2', 'total r^2'])
    #scores.set_index('iteration', inplace = True)
    for i in range(iterations):
        #develop model & scores
        forest = RandomForestRegressor()
        X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size = test_size, random_state = random_state)

        forest.fit(X_train, Y_train.reset_index().drop('Reaction', axis = 1).values.ravel())
        
        #evaluating performance
        Y_pred = forest.predict(X_test)

        results = pd.concat([Y_test.reset_index(), pd.DataFrame(Y_pred)], axis = 1)
        results.set_index('Reaction', inplace = True)
        results.columns = ['Actual', 'Predicted']

        Y_train_pred = forest.predict(X_train)
        train_results = pd.concat([Y_train.reset_index(), pd.DataFrame(Y_train_pred)], axis = 1)
        train_results.set_index('Reaction', inplace = True)
        train_results.columns = ['Actual', 'Predicted']

        all_results = pd.concat([train_results, results])
        
        scores = scores.append({'iteration': str(i+1),
                    'MSE': mean_squared_error(Y_test, Y_pred),
                    'r^2': r2_score(Y_test, Y_pred),
                    'total r^2': r2_score(all_results['Actual'], all_results['Predicted'])}, ignore_index = True)
        
        #evaluating most important features
        features = pd.concat([pd.DataFrame(X.columns), pd.DataFrame(forest.feature_importances_)], axis = 1)
        features.columns = ['Feature', 'Importance']
        features.set_index('Feature', inplace = True)
        
        if i == 0:
            total_features = features.sort_values(by = ['Importance'], ascending = False)
        else:
            for feature in total_features.index:
                total_features.loc[feature, 'Importance'] += features.loc[feature, 'Importance']
    
    #add average for each row
    averages = pd.DataFrame(scores.mean(axis = 0)).T
    scores = scores.append({'iteration': 'average',
                           'MSE': averages.iloc[0,1],
                           'r^2': averages.iloc[0,2],
                           'total r^2': averages.iloc[0,3]}, ignore_index = True)
    scores.set_index('iteration')
    
    #which stage each important feature is in
    for feature in total_features.index:
        if feature in solvent_columns:
            total_features.loc[feature, 'type'] = 'solvent'
        elif feature in nucleophile_columns:
            total_features.loc[feature, 'type'] = 'nucleophile'
        elif feature in catalyst_columns:
            total_features.loc[feature, 'type'] = 'catalyst'
        elif feature in iminium_columns:
            total_features.loc[feature, 'type'] = 'iminium'

    total_features = total_features[['type', 'Importance']]
    total_features = total_features.sort_values(by = ['Importance'], ascending = False)
    
    return scores, total_features

# %%
score, feature = run_random_forest_standard(100)

# %%
score
# Out:
#     iteration       MSE       r^2  total r^2
# 0           1  0.167519  0.944607   0.958691
# 1           2  0.183179  0.939318   0.953373
# 2           3  0.191884  0.939543   0.953725
# 3           4  0.169245  0.943731   0.957468
# 4           5  0.202532  0.934599   0.951862
# ..        ...       ...       ...        ...
# 96         97  0.211742  0.928714   0.951144
# 97         98  0.127635  0.957790   0.960941
# 98         99  0.154608  0.949176   0.958908
# 99        100  0.206295  0.933735   0.954084
# 100   average  0.203805  0.932763   0.952458
#
# [101 rows x 4 columns]
